# %% [markdown]
# <a href="https://colab.research.google.com/github/Hafiz-wave/Python-Notes/blob/main/Assignment_Module_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment Data Tools

# %% [markdown]
# ##**Muhammad Hafiz Bin Yahya**
# QA Data Analyst

# %% [markdown]
# *I wanted to integrate data science in pharmaceutical industries*

# %% [markdown]
# ###To Calculate Value of C

# %%
a=500
b=800
c=a-b
print(c)
# Out:
# -300

# %% [markdown]
# Characterisic of Data Analyst
#
# *   Critical Thinking
# *   Judgmental
# *   Argumentative
# *   Analytical Thinking
#
# Why Data Analyst?
#
#
#
# 1.   High in Demand
# 2.   Continuous Learning![machine.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd
df=pd.read_csv('custcat.csv')
df.head(20)
# Out:
#     region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0        2      13   44        1        9    64.0   4       5     0.0       0
# 1        3      11   33        1        7   136.0   5       5     0.0       0
# 2        3      68   52        1       24   116.0   1      29     0.0       1
# 3        2      33   33        0       12    33.0   2       0     0.0       1
# 4        2      23   30        1        9    30.0   1       2     0.0       0
# 5        2      41   39        0       17    78.0   2      16     0.0       1
# 6        3      45   22        1        2    19.0   2       4     0.0       1
# 7        2      38   35        0        5    76.0   2      10     0.0       0
# 8        3      45   59        1        7   166.0   4      31     0.0       0
# 9        1      68   41        1       21    72.0   1      22     0.0       0
# 10       2       5   33        0       10   125.0   4       5     0.0       1
# ...
